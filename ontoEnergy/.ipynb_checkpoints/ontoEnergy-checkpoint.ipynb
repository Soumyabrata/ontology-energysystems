# %%
import csv
import copy

from rdflib import URIRef, BNode, Literal
from rdflib.namespace import CSVW, DC, DCAT, DCTERMS, DOAP, FOAF, ODRL2, ORG, OWL, \
                           PROF, PROV, RDF, RDFS, SDO, SH, SKOS, SOSA, SSN, TIME, \
                           VOID, XMLNS, XSD
from rdflib import Namespace
from rdflib import Graph

from rdflib.extras.external_graph_libs import rdflib_to_networkx_multidigraph
import networkx as nx
import matplotlib.pyplot as plt

# %%
qudt = Namespace("http://qudt.org/1.1/schema/qudt#")
# cresource = Namespace("http://jresearch.ucd.ie/climate-kg/resource/")
seas = Namespace("https://w3id.org/seas/")
unit = Namespace("http://qudt.org/vocab/unit/")
prov = Namespace("http://www.w3.org/ns/prov#")
car = Namespace("http://jresearch.ucd.ie/climate-kg/resource/")

# %%
csvpath = './testenergy.csv'
with open(csvpath) as f:
    csvreader =  csv.reader(f)
    record_head = list(next(csvreader))
    record_rows = list(csvreader)

# %%
print(record_head)
# Out:
# ['\ufeffutc_timestamp', 'cet_cest_timestamp', 'DE_KN_industrial1_grid_import', 'DE_KN_industrial1_pv_1', 'DE_KN_industrial1_pv_2', 'DE_KN_industrial2_grid_import', 'DE_KN_industrial2_pv', 'DE_KN_industrial2_storage_charge', 'DE_KN_industrial2_storage_decharge', 'DE_KN_industrial3_area_offices', 'DE_KN_industrial3_area_room_1', 'DE_KN_industrial3_area_room_2', 'DE_KN_industrial3_area_room_3', 'DE_KN_industrial3_area_room_4', 'DE_KN_industrial3_compressor', 'DE_KN_industrial3_cooling_aggregate', 'DE_KN_industrial3_cooling_pumps', 'DE_KN_industrial3_dishwasher', 'DE_KN_industrial3_ev', 'DE_KN_industrial3_grid_import', 'DE_KN_industrial3_machine_1', 'DE_KN_industrial3_machine_2', 'DE_KN_industrial3_machine_3', 'DE_KN_industrial3_machine_4', 'DE_KN_industrial3_machine_5', 'DE_KN_industrial3_pv_facade', 'DE_KN_industrial3_pv_roof', 'DE_KN_industrial3_refrigerator', 'DE_KN_industrial3_ventilation', 'DE_KN_public1_grid_import', 'DE_KN_public2_grid_import', 'DE_KN_residential1_dishwasher', 'DE_KN_residential1_freezer', 'DE_KN_residential1_grid_import', 'DE_KN_residential1_heat_pump', 'DE_KN_residential1_pv', 'DE_KN_residential1_washing_machine', 'DE_KN_residential2_circulation_pump', 'DE_KN_residential2_dishwasher', 'DE_KN_residential2_freezer', 'DE_KN_residential2_grid_import', 'DE_KN_residential2_washing_machine', 'DE_KN_residential3_circulation_pump', 'DE_KN_residential3_dishwasher', 'DE_KN_residential3_freezer', 'DE_KN_residential3_grid_export', 'DE_KN_residential3_grid_import', 'DE_KN_residential3_pv', 'DE_KN_residential3_refrigerator', 'DE_KN_residential3_washing_machine', 'DE_KN_residential4_dishwasher', 'DE_KN_residential4_ev', 'DE_KN_residential4_freezer', 'DE_KN_residential4_grid_export', 'DE_KN_residential4_grid_import', 'DE_KN_residential4_heat_pump', 'DE_KN_residential4_pv', 'DE_KN_residential4_refrigerator', 'DE_KN_residential4_washing_machine', 'DE_KN_residential5_dishwasher', 'DE_KN_residential5_grid_import', 'DE_KN_residential5_refrigerator', 'DE_KN_residential5_washing_machine', 'DE_KN_residential6_circulation_pump', 'DE_KN_residential6_dishwasher', 'DE_KN_residential6_freezer', 'DE_KN_residential6_grid_export', 'DE_KN_residential6_grid_import', 'DE_KN_residential6_pv', 'DE_KN_residential6_washing_machine', 'interpolated']

# %%
def format_uri(*strs):
    uri = strs[0]
    i=1
    while(i>0 and i<len(strs)-1):
        uri += (strs[i]+"_")
        i = i+1
    uri += strs[-1]
    return URIRef(uri)

def ts_mapping_to_rdf(baseuri, header, record, time, graph):
    if record != "":
        header_uri = format_uri(baseuri,header)
        evaluation_uri = format_uri(baseuri,header,time)
        graph.add((evaluation_uri, RDF.type, seas.ElectricPowerEvaluation))
        graph.add((header_uri, seas.evaluation, evaluation_uri))
        graph.add((evaluation_uri,prov.generatedAtTime,Literal(time,datatype=XSD.dateTime)))
        evaluatiion_value_uri = format_uri(baseuri,header,time,"value")
        graph.add((evaluatiion_value_uri, RDF.type, qudt.QuantityValue))
        graph.add((evaluation_uri,seas.evaluatedValue, evaluatiion_value_uri))
        graph.add((evaluatiion_value_uri, qudt.numericalValue, Literal(record,datatype=XSD.float)))
        graph.add((evaluatiion_value_uri, qudt.unit,unit["KiloW-HR"]))

# %%
g = Graph()
g.bind("qudt", qudt)
g.bind("unit",unit)
g.bind("rdfs", RDFS)
g.bind("rdf", RDF)
g.bind("seas",seas)
g.bind("car",car)
g.bind("prov",prov)

# %%
baseuri = "http://jresearch.ucd.ie/climate-kg/resource/"
headers = copy.deepcopy(record_head)
headers.remove('\ufeffutc_timestamp')
headers.remove('cet_cest_timestamp')
headers.remove('interpolated')
for row in record_rows:
    for header in headers:
        ts_mapping_to_rdf(baseuri,header,row[record_head.index(header)],row[record_head.index(record_head[0])],g)
print(g.serialize(format="turtle").decode("utf-8"))
# Out:
# @prefix car: <http://jresearch.ucd.ie/climate-kg/resource/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix qudt: <http://qudt.org/1.1/schema/qudt#> .
# @prefix seas: <https://w3id.org/seas/> .
# @prefix unit: <http://qudt.org/vocab/unit/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# car:DE_KN_industrial1_grid_import seas:evaluation car:DE_KN_industrial1_grid_import_2016-03-04T16:00:00Z,
#         car:DE_KN_industrial1_grid_import_2016-03-04T17:00:00Z,
#         car:DE_KN_industrial1_grid_import_2016-03-04T18:00:00Z .
#
# car:DE_KN_industrial1_pv_1 seas:evaluation car:DE_KN_industrial1_pv_1_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial1_pv_1_2016-03-04T16:00:00Z,
#         car:DE_KN_industrial1_pv_1_2016-03-04T17:00:00Z,
#         car:DE_KN_industrial1_pv_1_2016-03-04T18:00:00Z .
#
# car:DE_KN_industrial1_pv_2 seas:evaluation car:DE_KN_industrial1_pv_2_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial1_pv_2_2016-03-04T16:00:00Z,
#         car:DE_KN_industrial1_pv_2_2016-03-04T17:00:00Z,
#         car:DE_KN_industrial1_pv_2_2016-03-04T18:00:00Z .
#
# car:DE_KN_industrial2_grid_import seas:evaluation car:DE_KN_industrial2_grid_import_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial2_grid_import_2016-03-04T16:00:00Z,
#         car:DE_KN_industrial2_grid_import_2016-03-04T17:00:00Z,
#         car:DE_KN_industrial2_grid_import_2016-03-04T18:00:00Z .
#
# car:DE_KN_industrial2_pv seas:evaluation car:DE_KN_industrial2_pv_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial2_pv_2016-03-04T16:00:00Z,
#         car:DE_KN_industrial2_pv_2016-03-04T17:00:00Z,
#         car:DE_KN_industrial2_pv_2016-03-04T18:00:00Z .
#
# car:DE_KN_industrial3_area_offices seas:evaluation car:DE_KN_industrial3_area_offices_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_area_offices_2016-03-04T16:00:00Z,
#         car:DE_KN_industrial3_area_offices_2016-03-04T17:00:00Z,
#         car:DE_KN_industrial3_area_offices_2016-03-04T18:00:00Z .
#
# car:DE_KN_industrial3_area_room_1 seas:evaluation car:DE_KN_industrial3_area_room_1_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_area_room_1_2016-03-04T16:00:00Z,
#         car:DE_KN_industrial3_area_room_1_2016-03-04T17:00:00Z,
#         car:DE_KN_industrial3_area_room_1_2016-03-04T18:00:00Z .
#
# car:DE_KN_industrial3_area_room_2 seas:evaluation car:DE_KN_industrial3_area_room_2_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_area_room_2_2016-03-04T16:00:00Z,
#         car:DE_KN_industrial3_area_room_2_2016-03-04T17:00:00Z,
#         car:DE_KN_industrial3_area_room_2_2016-03-04T18:00:00Z .
#
# car:DE_KN_industrial3_area_room_3 seas:evaluation car:DE_KN_industrial3_area_room_3_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_area_room_3_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_area_room_4 seas:evaluation car:DE_KN_industrial3_area_room_4_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_area_room_4_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_compressor seas:evaluation car:DE_KN_industrial3_compressor_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_compressor_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_cooling_aggregate seas:evaluation car:DE_KN_industrial3_cooling_aggregate_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_cooling_aggregate_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_cooling_pumps seas:evaluation car:DE_KN_industrial3_cooling_pumps_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_cooling_pumps_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_dishwasher seas:evaluation car:DE_KN_industrial3_dishwasher_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_dishwasher_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_grid_import seas:evaluation car:DE_KN_industrial3_grid_import_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_grid_import_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_machine_1 seas:evaluation car:DE_KN_industrial3_machine_1_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_machine_1_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_machine_2 seas:evaluation car:DE_KN_industrial3_machine_2_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_machine_2_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_machine_3 seas:evaluation car:DE_KN_industrial3_machine_3_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_machine_3_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_machine_4 seas:evaluation car:DE_KN_industrial3_machine_4_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_machine_4_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_machine_5 seas:evaluation car:DE_KN_industrial3_machine_5_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_machine_5_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_pv_facade seas:evaluation car:DE_KN_industrial3_pv_facade_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_pv_facade_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_pv_roof seas:evaluation car:DE_KN_industrial3_pv_roof_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_pv_roof_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_refrigerator seas:evaluation car:DE_KN_industrial3_refrigerator_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_refrigerator_2016-03-04T16:00:00Z .
#
# car:DE_KN_industrial3_ventilation seas:evaluation car:DE_KN_industrial3_ventilation_2016-03-04T15:00:00Z,
#         car:DE_KN_industrial3_ventilation_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential1_dishwasher seas:evaluation car:DE_KN_residential1_dishwasher_2016-03-04T15:00:00Z,
#         car:DE_KN_residential1_dishwasher_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential1_freezer seas:evaluation car:DE_KN_residential1_freezer_2016-03-04T15:00:00Z,
#         car:DE_KN_residential1_freezer_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential1_grid_import seas:evaluation car:DE_KN_residential1_grid_import_2016-03-04T15:00:00Z,
#         car:DE_KN_residential1_grid_import_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential1_heat_pump seas:evaluation car:DE_KN_residential1_heat_pump_2016-03-04T15:00:00Z,
#         car:DE_KN_residential1_heat_pump_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential1_pv seas:evaluation car:DE_KN_residential1_pv_2016-03-04T15:00:00Z,
#         car:DE_KN_residential1_pv_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential1_washing_machine seas:evaluation car:DE_KN_residential1_washing_machine_2016-03-04T15:00:00Z,
#         car:DE_KN_residential1_washing_machine_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential2_circulation_pump seas:evaluation car:DE_KN_residential2_circulation_pump_2016-03-04T15:00:00Z,
#         car:DE_KN_residential2_circulation_pump_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential2_dishwasher seas:evaluation car:DE_KN_residential2_dishwasher_2016-03-04T15:00:00Z,
#         car:DE_KN_residential2_dishwasher_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential2_freezer seas:evaluation car:DE_KN_residential2_freezer_2016-03-04T15:00:00Z,
#         car:DE_KN_residential2_freezer_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential2_grid_import seas:evaluation car:DE_KN_residential2_grid_import_2016-03-04T15:00:00Z,
#         car:DE_KN_residential2_grid_import_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential2_washing_machine seas:evaluation car:DE_KN_residential2_washing_machine_2016-03-04T15:00:00Z,
#         car:DE_KN_residential2_washing_machine_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential3_circulation_pump seas:evaluation car:DE_KN_residential3_circulation_pump_2016-03-04T15:00:00Z,
#         car:DE_KN_residential3_circulation_pump_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential3_dishwasher seas:evaluation car:DE_KN_residential3_dishwasher_2016-03-04T15:00:00Z,
#         car:DE_KN_residential3_dishwasher_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential3_freezer seas:evaluation car:DE_KN_residential3_freezer_2016-03-04T15:00:00Z,
#         car:DE_KN_residential3_freezer_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential3_grid_export seas:evaluation car:DE_KN_residential3_grid_export_2016-03-04T15:00:00Z,
#         car:DE_KN_residential3_grid_export_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential3_grid_import seas:evaluation car:DE_KN_residential3_grid_import_2016-03-04T15:00:00Z,
#         car:DE_KN_residential3_grid_import_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential3_pv seas:evaluation car:DE_KN_residential3_pv_2016-03-04T15:00:00Z,
#         car:DE_KN_residential3_pv_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential3_refrigerator seas:evaluation car:DE_KN_residential3_refrigerator_2016-03-04T15:00:00Z,
#         car:DE_KN_residential3_refrigerator_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential3_washing_machine seas:evaluation car:DE_KN_residential3_washing_machine_2016-03-04T15:00:00Z,
#         car:DE_KN_residential3_washing_machine_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential4_dishwasher seas:evaluation car:DE_KN_residential4_dishwasher_2016-03-04T15:00:00Z,
#         car:DE_KN_residential4_dishwasher_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential4_ev seas:evaluation car:DE_KN_residential4_ev_2016-03-04T15:00:00Z,
#         car:DE_KN_residential4_ev_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential4_freezer seas:evaluation car:DE_KN_residential4_freezer_2016-03-04T15:00:00Z,
#         car:DE_KN_residential4_freezer_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential4_grid_export seas:evaluation car:DE_KN_residential4_grid_export_2016-03-04T15:00:00Z,
#         car:DE_KN_residential4_grid_export_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential4_grid_import seas:evaluation car:DE_KN_residential4_grid_import_2016-03-04T15:00:00Z,
#         car:DE_KN_residential4_grid_import_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential4_heat_pump seas:evaluation car:DE_KN_residential4_heat_pump_2016-03-04T15:00:00Z,
#         car:DE_KN_residential4_heat_pump_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential4_pv seas:evaluation car:DE_KN_residential4_pv_2016-03-04T15:00:00Z,
#         car:DE_KN_residential4_pv_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential4_refrigerator seas:evaluation car:DE_KN_residential4_refrigerator_2016-03-04T15:00:00Z,
#         car:DE_KN_residential4_refrigerator_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential4_washing_machine seas:evaluation car:DE_KN_residential4_washing_machine_2016-03-04T15:00:00Z,
#         car:DE_KN_residential4_washing_machine_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential5_dishwasher seas:evaluation car:DE_KN_residential5_dishwasher_2016-03-04T15:00:00Z,
#         car:DE_KN_residential5_dishwasher_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential5_grid_import seas:evaluation car:DE_KN_residential5_grid_import_2016-03-04T15:00:00Z,
#         car:DE_KN_residential5_grid_import_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential5_refrigerator seas:evaluation car:DE_KN_residential5_refrigerator_2016-03-04T15:00:00Z,
#         car:DE_KN_residential5_refrigerator_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential5_washing_machine seas:evaluation car:DE_KN_residential5_washing_machine_2016-03-04T15:00:00Z,
#         car:DE_KN_residential5_washing_machine_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential6_circulation_pump seas:evaluation car:DE_KN_residential6_circulation_pump_2016-03-04T15:00:00Z,
#         car:DE_KN_residential6_circulation_pump_2016-03-04T16:00:00Z .
#
# car:DE_KN_residential6_dishwasher seas:evaluation car:DE_KN_residential6_dishwasher_2016-03-04T15:00:00Z,
#         car:DE_KN_residential6_dishwasher_2016-03-04T16:00:00Z .
#
# car:DE_KN_resid
2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_grid_export_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential4_grid_export_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "1220.965"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_grid_import_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_grid_import_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential4_grid_import_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "2458.476"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_grid_import_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_grid_import_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential4_grid_import_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "2459.381"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_heat_pump_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_heat_pump_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential4_heat_pump_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "1813.689"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_heat_pump_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_heat_pump_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential4_heat_pump_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "1814.329"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_pv_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_pv_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential4_pv_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "1955.549"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_pv_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_pv_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential4_pv_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "1955.658"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_refrigerator_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_refrigerator_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential4_refrigerator_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "52.676"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_refrigerator_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_refrigerator_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential4_refrigerator_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "52.709"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_washing_machine_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_washing_machine_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential4_washing_machine_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "41.907"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential4_washing_machine_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential4_washing_machine_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential4_washing_machine_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "41.907"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential5_dishwasher_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential5_dishwasher_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential5_dishwasher_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "100.194"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential5_dishwasher_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential5_dishwasher_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential5_dishwasher_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "100.195"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential5_grid_import_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential5_grid_import_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential5_grid_import_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "1128.349"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential5_grid_import_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential5_grid_import_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential5_grid_import_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "1128.599"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential5_refrigerator_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential5_refrigerator_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential5_refrigerator_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "115.608"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential5_refrigerator_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential5_refrigerator_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential5_refrigerator_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "115.681"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential5_washing_machine_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential5_washing_machine_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential5_washing_machine_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "82.171"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential5_washing_machine_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential5_washing_machine_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential5_washing_machine_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "82.171"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_circulation_pump_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_circulation_pump_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential6_circulation_pump_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "152.15"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_circulation_pump_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_circulation_pump_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential6_circulation_pump_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "152.179"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_dishwasher_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_dishwasher_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential6_dishwasher_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "16.521"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_dishwasher_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_dishwasher_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential6_dishwasher_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "16.521"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_freezer_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_freezer_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential6_freezer_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "61.367"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_freezer_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_freezer_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential6_freezer_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "61.393"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_grid_import_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_grid_import_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential6_grid_import_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "2026.333"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_grid_import_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_grid_import_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential6_grid_import_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "2027.148"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_pv_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_pv_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential6_pv_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "1000.791"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_pv_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_pv_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential6_pv_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "1000.803"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_washing_machine_2016-03-04T15:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T15:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_washing_machine_2016-03-04T15:00:00Z_value .
#
# car:DE_KN_residential6_washing_machine_2016-03-04T15:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "19.593"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .
#
# car:DE_KN_residential6_washing_machine_2016-03-04T16:00:00Z a seas:ElectricPowerEvaluation ;
#     prov:generatedAtTime "2016-03-04T16:00:00+00:00"^^xsd:dateTime ;
#     seas:evaluatedValue car:DE_KN_residential6_washing_machine_2016-03-04T16:00:00Z_value .
#
# car:DE_KN_residential6_washing_machine_2016-03-04T16:00:00Z_value a qudt:QuantityValue ;
#     qudt:numericalValue "19.594"^^xsd:float ;
#     qudt:unit unit:KiloW-HR .

# %%
path ='./individuals.owl'

g = Graph()
result = g.parse(path, format='turtle')

G = rdflib_to_networkx_multidigraph(result)

# Plot Networkx instance of RDF Graph
pos = nx.spring_layout(G, scale=2)
edge_labels = nx.get_edge_attributes(G, 'r')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
nx.draw(G, with_labels=True)
